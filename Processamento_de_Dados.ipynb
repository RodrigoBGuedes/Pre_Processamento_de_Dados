# %%
#Importação de bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importação de dados
dados = pd.read_csv('data.csv')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Columns: 144 entries, R_fighter to R_age
# dtypes: bool(1), float64(106), int64(28), object(9)
# memory usage: 6.6+ MB

# %%
dados.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight     0.500
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight       NaN
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight       NaN
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight     0.125
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0           0.0  ...                            0                1
# 1           0.0  ...                            0                3
# 2           NaN  ...                            1                3
# 3           NaN  ...                            0                0
# 4           0.0  ...                            1                2
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms  \
# 0                    0                             0  Orthodox        170.18
# 1                    0                             0  Orthodox        182.88
# 2                    0                             0  Southpaw        187.96
# 3                    0                             0    Switch        160.02
# 4                    2                             0  Orthodox        167.64
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       177.80         135.0   31.0   27.0
# 1       187.96         185.0   32.0   28.0
# 2       190.50         264.0   32.0   28.0
# 3       160.02         115.0   28.0   25.0
# 4       172.72         135.0   29.0   43.0
#
# [5 rows x 144 columns]

# %%
df = dados[['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner', 'title_bout', 'weight_class', 
            'B_total_rounds_fought','B_total_title_bouts', 'B_wins', 'B_losses', 'B_draw', 'B_win_by_KO/TKO', 'B_Stance', 
            'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs', 'B_age',
            'R_total_rounds_fought','R_total_title_bouts', 'R_wins', 'R_losses', 'R_draw', 'R_win_by_KO/TKO', 'R_Stance', 
            'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs', 'R_age']]

# %%
df.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight
#
#    B_total_rounds_fought  B_total_title_bouts  ...  R_total_title_bouts  \
# 0                      4                    0  ...                    0
# 1                      4                    0  ...                    0
# 2                      0                    0  ...                    0
# 3                      0                    0  ...                    0
# 4                     11                    1  ...                    0
#
#    R_wins  R_losses  R_draw R_win_by_KO/TKO  R_Stance  R_Height_cms  \
# 0       1         0       0               1  Orthodox        170.18
# 1       4         2       0               3  Orthodox        182.88
# 2       4         3       0               3  Southpaw        187.96
# 3       0         0       0               0    Switch        160.02
# 4       5         6       0               2  Orthodox        167.64
#
#    R_Reach_cms  R_Weight_lbs  R_age
# 0       177.80         135.0   27.0
# 1       187.96         185.0   28.0
# 2       190.50         264.0   28.0
# 3       160.02         115.0   25.0
# 4       172.72         135.0   43.0
#
# [5 rows x 30 columns]

# %%
divisao = df["location"].str.split(',')

# %%
divisao
# Out:
# 0       [Las Vegas,  Nevada,  USA]
# 1       [Las Vegas,  Nevada,  USA]
# 2       [Las Vegas,  Nevada,  USA]
# 3       [Las Vegas,  Nevada,  USA]
# 4       [Las Vegas,  Nevada,  USA]
#                    ...
# 6007     [Denver,  Colorado,  USA]
# 6008     [Denver,  Colorado,  USA]
# 6009     [Denver,  Colorado,  USA]
# 6010     [Denver,  Colorado,  USA]
# 6011     [Denver,  Colorado,  USA]
# Name: location, Length: 6012, dtype: object

# %%
cidade_estado = divisao.str.get(0) + ", " + divisao.str.get(1)
pais = divisao.str.get(2)

# %%
df["City/State"] = cidade_estado
df["Country"] = pais
# Out:
# C:\Users\gedsa\AppData\Local\Temp\ipykernel_18260\928709201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City/State"] = cidade_estado
# C:\Users\gedsa\AppData\Local\Temp\ipykernel_18260\928709201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Country"] = pais

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   R_fighter              6012 non-null   object
#  1   B_fighter              6012 non-null   object
#  2   Referee                5980 non-null   object
#  3   date                   6012 non-null   object
#  4   location               6012 non-null   object
#  5   Winner                 6012 non-null   object
#  6   title_bout             6012 non-null   bool
#  7   weight_class           6012 non-null   object
#  8   B_total_rounds_fought  6012 non-null   int64
#  9   B_total_title_bouts    6012 non-null   int64
#  10  B_wins                 6012 non-null   int64
#  11  B_losses               6012 non-null   int64
#  12  B_draw                 6012 non-null   int64
#  13  B_win_by_KO/TKO        6012 non-null   int64
#  14  B_Stance               5946 non-null   object
#  15  B_Height_cms           6002 non-null   float64
#  16  B_Reach_cms            5121 non-null   float64
#  17  B_Weight_lbs           6004 non-null   float64
#  18  B_age                  5840 non-null   float64
#  19  R_total_rounds_fought  6012 non-null   int64
#  20  R_total_title_bouts    6012 non-null   int64
#  21  R_wins                 6012 non-null   int64
#  22  R_losses               6012 non-null   int64
#  23  R_draw                 6012 non-null   int64
#  24  R_win_by_KO/TKO        6012 non-null   int64
#  25  R_Stance               5983 non-null   object
#  26  R_Height_cms           6008 non-null   float64
#  27  R_Reach_cms            5606 non-null   float64
#  28  R_Weight_lbs           6010 non-null   float64
#  29  R_age                  5949 non-null   float64
#  30  City/State             6012 non-null   object
#  31  Country                5498 non-null   object
# dtypes: bool(1), float64(8), int64(12), object(11)
# memory usage: 1.4+ MB

# %%
#Retira os dados nulos
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4517 entries, 0 to 5884
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   R_fighter              4517 non-null   object
#  1   B_fighter              4517 non-null   object
#  2   Referee                4517 non-null   object
#  3   date                   4517 non-null   object
#  4   location               4517 non-null   object
#  5   Winner                 4517 non-null   object
#  6   title_bout             4517 non-null   bool
#  7   weight_class           4517 non-null   object
#  8   B_total_rounds_fought  4517 non-null   int64
#  9   B_total_title_bouts    4517 non-null   int64
#  10  B_wins                 4517 non-null   int64
#  11  B_losses               4517 non-null   int64
#  12  B_draw                 4517 non-null   int64
#  13  B_win_by_KO/TKO        4517 non-null   int64
#  14  B_Stance               4517 non-null   object
#  15  B_Height_cms           4517 non-null   float64
#  16  B_Reach_cms            4517 non-null   float64
#  17  B_Weight_lbs           4517 non-null   float64
#  18  B_age                  4517 non-null   float64
#  19  R_total_rounds_fought  4517 non-null   int64
#  20  R_total_title_bouts    4517 non-null   int64
#  21  R_wins                 4517 non-null   int64
#  22  R_losses               4517 non-null   int64
#  23  R_draw                 4517 non-null   int64
#  24  R_win_by_KO/TKO        4517 non-null   int64
#  25  R_Stance               4517 non-null   object
#  26  R_Height_cms           4517 non-null   float64
#  27  R_Reach_cms            4517 non-null   float64
#  28  R_Weight_lbs           4517 non-null   float64
#  29  R_age                  4517 non-null   float64
#  30  City/State             4517 non-null   object
#  31  Country                4517 non-null   object
# dtypes: bool(1), float64(8), int64(12), object(11)
# memory usage: 1.1+ MB

# %%
df = df[['R_fighter', 'B_fighter', 'Referee', 'date', 'City/State', 'Country', 'Winner', 'title_bout', 'weight_class', 
            'B_total_rounds_fought','B_total_title_bouts', 'B_wins', 'B_losses', 'B_draw', 'B_win_by_KO/TKO', 'B_Stance', 
            'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs', 'B_age',
            'R_total_rounds_fought','R_total_title_bouts', 'R_wins', 'R_losses', 'R_draw', 'R_win_by_KO/TKO', 'R_Stance', 
            'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs', 'R_age']]

# %%
df.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#            City/State Country Winner  title_bout       weight_class  \
# 0  Las Vegas,  Nevada     USA    Red       False       Bantamweight
# 1  Las Vegas,  Nevada     USA    Red       False       Middleweight
# 2  Las Vegas,  Nevada     USA    Red       False        Heavyweight
# 3  Las Vegas,  Nevada     USA   Blue       False   WomenStrawweight
# 4  Las Vegas,  Nevada     USA   Blue       False  WomenBantamweight
#
#    B_total_rounds_fought  ...  R_total_title_bouts  R_wins  R_losses  R_draw  \
# 0                      4  ...                    0       1         0       0
# 1                      4  ...                    0       4         2       0
# 2                      0  ...                    0       4         3       0
# 3                      0  ...                    0       0         0       0
# 4                     11  ...                    0       5         6       0
#
#    R_win_by_KO/TKO  R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  R_age
# 0                1  Orthodox        170.18       177.80         135.0   27.0
# 1                3  Orthodox        182.88       187.96         185.0   28.0
# 2                3  Southpaw        187.96       190.50         264.0   28.0
# 3                0    Switch        160.02       160.02         115.0   25.0
# 4                2  Orthodox        167.64       172.72         135.0   43.0
#
# [5 rows x 31 columns]

# %%
#Criação do dataframe do lado Vermelho
df_red = df[['R_fighter','weight_class', 'R_age','R_total_rounds_fought','R_total_title_bouts', 
             'R_wins', 'R_losses', 'R_draw', 'R_win_by_KO/TKO', 'R_Stance', 
            'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs']]

# %%
df_red.head()
# Out:
#        R_fighter       weight_class  R_age  R_total_rounds_fought  \
# 0   Adrian Yanez       Bantamweight   27.0                      1
# 1   Trevin Giles       Middleweight   28.0                     17
# 2    Tai Tuivasa        Heavyweight   28.0                     13
# 3  Cheyanne Buys   WomenStrawweight   25.0                      0
# 4  Marion Reneau  WomenBantamweight   43.0                     30
#
#    R_total_title_bouts  R_wins  R_losses  R_draw  R_win_by_KO/TKO  R_Stance  \
# 0                    0       1         0       0                1  Orthodox
# 1                    0       4         2       0                3  Orthodox
# 2                    0       4         3       0                3  Southpaw
# 3                    0       0         0       0                0    Switch
# 4                    0       5         6       0                2  Orthodox
#
#    R_Height_cms  R_Reach_cms  R_Weight_lbs
# 0        170.18       177.80         135.0
# 1        182.88       187.96         185.0
# 2        187.96       190.50         264.0
# 3        160.02       160.02         115.0
# 4        167.64       172.72         135.0

# %%
#Criação do dataframe do lado azul
df_blue = df[['B_fighter', 'weight_class','B_age', 'B_total_rounds_fought','B_total_title_bouts', 
              'B_wins', 'B_losses', 'B_draw', 'B_win_by_KO/TKO', 'B_Stance', 
              'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs']]

# %%
df_blue.head()
# Out:
#            B_fighter       weight_class  B_age  B_total_rounds_fought  \
# 0      Gustavo Lopez       Bantamweight   31.0                      4
# 1      Roman Dolidze       Middleweight   32.0                      4
# 2    Harry Hunsucker        Heavyweight   32.0                      0
# 3  Montserrat Conejo   WomenStrawweight   28.0                      0
# 4      Macy Chiasson  WomenBantamweight   29.0                     11
#
#    B_total_title_bouts  B_wins  B_losses  B_draw  B_win_by_KO/TKO  B_Stance  \
# 0                    0       1         1       0                0  Orthodox
# 1                    0       2         0       0                1  Orthodox
# 2                    0       0         0       0                0  Orthodox
# 3                    0       0         0       0                0  Southpaw
# 4                    1       4         1       0                2  Orthodox
#
#    B_Height_cms  B_Reach_cms  B_Weight_lbs
# 0        165.10       170.18         135.0
# 1        187.96       193.04         205.0
# 2        187.96       190.50         241.0
# 3        152.40       154.94         115.0
# 4        180.34       182.88         135.0

# %%
#Dataframe das lutas
df_fight = df[['R_fighter', 'B_fighter', 'Referee', 'date', 'City/State', 
               'Country', 'Winner', 'title_bout', 'weight_class']]

# %%
df_fight.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#            City/State Country Winner  title_bout       weight_class
# 0  Las Vegas,  Nevada     USA    Red       False       Bantamweight
# 1  Las Vegas,  Nevada     USA    Red       False       Middleweight
# 2  Las Vegas,  Nevada     USA    Red       False        Heavyweight
# 3  Las Vegas,  Nevada     USA   Blue       False   WomenStrawweight
# 4  Las Vegas,  Nevada     USA   Blue       False  WomenBantamweight

# %% [markdown]
# # Contando as categorias de peso

# %%
df['weight_class'].value_counts()
# Out:
# Lightweight           835
# Welterweight          809
# Middleweight          603
# LightHeavyweight      452
# Featherweight         439
# Bantamweight          387
# Heavyweight           371
# Flyweight             194
# WomenStrawweight      162
# WomenBantamweight     121
# WomenFlyweight         93
# CatchWeight            36
# WomenFeatherweight     15
# Name: weight_class, dtype: int64

# %%
df['weight_class'].value_counts().plot.bar(title="Categorias de peso",figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Categorias de peso'}>

# %% [markdown]
# # Contando a posição dominante

# %%
df['R_Stance'].value_counts().head()
# Out:
# Orthodox       3405
# Southpaw        962
# Switch          139
# Open Stance      11
# Name: R_Stance, dtype: int64

# %%
df['R_Stance'].value_counts().plot.pie( title="Mão dominante",figsize=(6,6))
# Out:
# <AxesSubplot:title={'center':'Mão dominante'}, ylabel='R_Stance'>

# %% [markdown]
# # Separando por partidas que ocorreram títulos

# %%
to_drop = df_fight['title_bout'] == True

# %%
df_titulos = df_fight[to_drop]
df_titulos
# Out:
#                 R_fighter             B_fighter         Referee        date  \
# 25               Petr Yan     Aljamain Sterling      Mark Smith  2021-03-06
# 26         Jan Blachowicz       Israel Adesanya       Herb Dean  2021-03-06
# 29           Amanda Nunes        Megan Anderson    Jason Herzog  2021-03-06
# 62           Kamaru Usman         Gilbert Burns       Herb Dean  2021-02-13
# 132   Deiveson Figueiredo        Brandon Moreno    Jason Herzog  2020-12-12
# ...                   ...                   ...             ...         ...
# 5737           Tito Ortiz  Vladimir Matyushenko   John McCarthy  2001-09-28
# 5739          Jens Pulver        Dennis Hallman  Mario Yamasaki  2001-09-28
# 5744           Tito Ortiz         Elvis Sinosic   John McCarthy  2001-06-29
# 5759           Tito Ortiz           Evan Tanner   John McCarthy  2001-02-23
# 5760          Jens Pulver              Caol Uno   John McCarthy  2001-02-23
#
#                         City/State Country Winner  title_bout  \
# 25              Las Vegas,  Nevada     USA   Blue        True
# 26              Las Vegas,  Nevada     USA    Red        True
# 29              Las Vegas,  Nevada     USA    Red        True
# 62              Las Vegas,  Nevada     USA    Red        True
# 132             Las Vegas,  Nevada     USA   Draw        True
# ...                            ...     ...    ...         ...
# 5737            Las Vegas,  Nevada     USA    Red        True
# 5739            Las Vegas,  Nevada     USA    Red        True
# 5744  East Rutherford,  New Jersey     USA    Red        True
# 5759    Atlantic City,  New Jersey     USA    Red        True
# 5760    Atlantic City,  New Jersey     USA    Red        True
#
#             weight_class
# 25          Bantamweight
# 26      LightHeavyweight
# 29    WomenFeatherweight
# 62          Welterweight
# 132            Flyweight
# ...                  ...
# 5737    LightHeavyweight
# 5739         Lightweight
# 5744    LightHeavyweight
# 5759    LightHeavyweight
# 5760         Lightweight
#
# [285 rows x 9 columns]

# %%
df_titulos['Country'].value_counts()
# Out:
#  USA                     231
#  Canada                   23
#  United Arab Emirates      8
#  Brazil                    8
#  Australia                 5
#  Mexico                    4
#  United Kingdom            4
#  China                     1
#  Germany                   1
# Name: Country, dtype: int64

# %%
df_titulos['Country'].value_counts().plot.pie(y='Paises', title="Países que mais ocorreram lutas de titulo",figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Países que mais ocorreram lutas de titulo'}, ylabel='Country'>

# %%
df_titulos['City/State'].value_counts()
# Out:
# Las Vegas,  Nevada                 132
# Toronto,  Ontario                   10
# Anaheim,  California                 9
# Abu Dhabi,  Abu Dhabi                8
# Los Angeles,  California             8
# New York City,  New York             7
# Montreal,  Quebec                    7
# Houston,  Texas                      7
# Sacramento,  California              6
# Newark,  New Jersey                  6
# Dallas,  Texas                       6
# Chicago,  Illinois                   5
# Atlantic City,  New Jersey           5
# Mexico City,  Distrito Federal       4
# Boston,  Massachusetts               4
# Brooklyn,  New York                  4
# Atlanta,  Georgia                    4
# Rio de Janeiro,  Rio de Janeiro      4
# Melbourne,  Victoria                 3
# Uncasville,  Connecticut             3
# Jacksonville,  Florida               2
# Columbus,  Ohio                      2
# Belo Horizonte,  Minas Gerais        2
# Denver,  Colorado                    2
# London,  England                     2
# Seattle,  Washington                 2
# Edmonton,  Alberta                   2
# Quebec City,  Quebec                 2
# Berlin,  Berlin                      1
# Washington,  DC                      1
# Miami,  Florida                      1
# Shenzhen,  Guangdong                 1
# Perth,  Western Australia            1
# Cincinnati,  Ohio                    1
# Newcastle,  England                  1
# Detroit,  Michigan                   1
# Minneapolis,  Minnesota              1
# Rosemont,  Illinois                  1
# Philadelphia,  Pennsylvania          1
# Memphis,  Tennessee                  1
# Oakland,  California                 1
# Kansas City,  Missouri               1
# Vancouver,  British Columbia         1
# Calgary,  Alberta                    1
# Buffalo,  New York                   1
# Gold Coast,  Queensland              1
# Manchester,  England                 1
# San Jose,  California                1
# Fortaleza,  Ceara                    1
# Cleveland,  Ohio                     1
# Milwaukee,  Wisconsin                1
# Curitiba,  Parana                    1
# Orlando,  Florida                    1
# Baltimore,  Maryland                 1
# East Rutherford,  New Jersey         1
# Name: City/State, dtype: int64

# %%
df_titulos['City/State'].value_counts().plot.bar(y='Cidade/Estados', title="Cidade/Estado que sediaram a luta",figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Cidade/Estado que sediaram a luta'}>

# %%
df_titulos['Referee'].value_counts().head(10)
# Out:
# Herb Dean           87
# John McCarthy       71
# Marc Goddard        23
# Yves Lavigne        21
# Dan Miragliotta     16
# Steve Mazzagatti    13
# Mario Yamasaki      12
# Keith Peterson       8
# Jason Herzog         6
# Josh Rosenthal       6
# Name: Referee, dtype: int64

# %%
df_titulos['Referee'].value_counts().head(10).plot.pie(y='Juizes', title='10 Árbritos que mais participaram de titulos',figsize=(7,7))
# Out:
# <AxesSubplot:title={'center':'10 Árbritos que mais participaram de titulos'}, ylabel='Referee'>

# %% [markdown]
# # Lutadores que mais venceram nos ultimos 10 anos

# %%
# Mudando o indice para filtrar os ultimos 10 anos
df.set_index('date', inplace=True)

# selecionando as lutas dos ultimos 10 anos 
df = df.loc['2019-06-08':'2010-01-0']

# Tirando as colunas que não interessam
important_dataall = df[['R_fighter', 'B_fighter', 'Winner']]
important_datared = df[['R_fighter', 'B_fighter', 'Winner']]
important_datablue = df[['R_fighter', 'B_fighter', 'Winner']]
important_dataall.head()
# Out:
#                        R_fighter      B_fighter Winner
# date
# 2019-06-08     Aljamain Sterling   Pedro Munhoz    Red
# 2019-06-08        Tatiana Suarez  Nina Ansaroff    Red
# 2019-06-08           Tai Tuivasa  Blagoy Ivanov   Blue
# 2019-06-08  Valentina Shevchenko    Jessica Eye    Red
# 2019-06-08         Jimmie Rivera       Petr Yan   Blue

# %%
def get_winner(row):
    if row['Winner'] == 'Red':
        return row['R_fighter']
    elif row['Winner'] == 'Blue':
        return row['B_fighter']
    else:
        return None
    
#
pd.options.mode.chained_assignment = None 

# Salvando o nome do vencedor na nova coluna
important_dataall['Winner_name'] = important_dataall.apply(get_winner, axis=1)

# Contando as ocorrencias de cada nome
winner = important_dataall['Winner_name']
winner.value_counts().head()
# Out:
# Donald Cerrone        23
# Dustin Poirier        17
# Jon Jones             15
# Rafael Dos Anjos      15
# Demetrious Johnson    15
# Name: Winner_name, dtype: int64

# %%
winner.value_counts().head(10).plot.bar(y='nomes', title='Lutares que mais venceram',figsize=(7,7))
# Out:
# <AxesSubplot:title={'center':'Lutares que mais venceram'}>

# %%
def get_winnerblue(row):
    if row['Winner'] == 'Blue':
        return row['B_fighter']
    else:
        return None
    
#
pd.options.mode.chained_assignment = None 

# Salvando o nome do vencedor na nova coluna
important_datablue['Winner_name'] = important_datablue.apply(get_winnerblue, axis=1)

# Contando as ocorrencias de cada nome
winnerblue = important_datablue['Winner_name']
winnerblue.value_counts().head()
# Out:
# Charles Oliveira    8
# Kevin Lee           8
# Darren Elkins       7
# Jeremy Stephens     7
# Rafael Dos Anjos    7
# Name: Winner_name, dtype: int64

# %%
winnerblue.value_counts().head(10).plot.bar(y='nomes', title='Lutares que mais venceram do lado azul',figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Lutares que mais venceram do lado azul'}>

# %%
def get_winnerred(row):
    if row['Winner'] == 'Red':
        return row['R_fighter']
    else:
        return None
    
#
pd.options.mode.chained_assignment = None 

# Salvando o nome do vencedor na nova coluna
important_dataall['Winner_name'] = important_dataall.apply(get_winnerred, axis=1)

# Contando as ocorrencias de cada nome
winnerred = important_dataall['Winner_name']
winnerred.value_counts().head()
# Out:
# Donald Cerrone      18
# Dustin Poirier      14
# Jim Miller          13
# Jon Jones           13
# Joseph Benavidez    12
# Name: Winner_name, dtype: int64

# %%
winnerred.value_counts().head(10).plot.bar(y='nomes', title='Lutares que mais venceram do lado vermelho',figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Lutares que mais venceram do lado vermelho'}>

# %% [markdown]
# # Lutadores que mais venceram por KO/TKO

# %%
df_KO_TKO = df[["R_fighter","B_fighter","Winner","B_win_by_KO/TKO",'R_win_by_KO/TKO']]

# %%
df_KO_TKO
# Out:
#                        R_fighter       B_fighter Winner  B_win_by_KO/TKO  \
# date
# 2019-06-08     Aljamain Sterling    Pedro Munhoz    Red                3
# 2019-06-08        Tatiana Suarez   Nina Ansaroff    Red                0
# 2019-06-08           Tai Tuivasa   Blagoy Ivanov   Blue                0
# 2019-06-08  Valentina Shevchenko     Jessica Eye    Red                0
# 2019-06-08         Jimmie Rivera        Petr Yan   Blue                2
# ...                          ...             ...    ...              ...
# 2010-01-02             Sam Stout      Joe Lauzon    Red                2
# 2010-01-02          Rashad Evans    Thiago Silva    Red                5
# 2010-01-02            Mark Munoz     Ryan Jensen    Red                0
# 2010-01-02     Rafaello Oliveira  John Gunderson    Red                0
# 2010-01-02      Jake Ellenberger       Mike Pyle    Red                0
#
#             R_win_by_KO/TKO
# date
# 2019-06-08                1
# 2019-06-08                1
# 2019-06-08                2
# 2019-06-08                0
# 2019-06-08                1
# ...                     ...
# 2010-01-02                0
# 2010-01-02                4
# 2010-01-02                0
# 2010-01-02                0
# 2010-01-02                0
#
# [3108 rows x 5 columns]

# %%
#separando em dois dataframes "azul" e "vermelho"
df_blue = pd.DataFrame(df_KO_TKO.groupby(['B_fighter'], sort=False)['B_win_by_KO/TKO'].max())
df_red = pd.DataFrame(df_KO_TKO.groupby(['R_fighter'], sort=False)['R_win_by_KO/TKO'].max())

# %%
#Filtrando mais o dataframe "azul"
df_blue["fighter"] = df_blue.index
df_blue.set_index(np.arange(1062),inplace =True)
df_blue = df_blue[["fighter",'B_win_by_KO/TKO']]
df_blue["KO/TKO"] = df_blue["B_win_by_KO/TKO"]
del df_blue["B_win_by_KO/TKO"]

# %%
#Filtrando mais o dataframe "vermelho"
df_red["fighter"] = df_red.index
df_red.set_index(np.arange(927),inplace =True)
df_red.rename(columns={'R_win_by_KO/TKO':'KO/TKO'},inplace =True)
df_red = df_red[["fighter",'KO/TKO']]

# %%
#Juntando os dois dataframes
df_KO_TKO1 = pd.concat([df_red,df_blue])
df_KOS = pd.DataFrame(df_KO_TKO1.groupby(['fighter'], sort=False)['KO/TKO'].max())

# %%
#Ajustando o maior numero de KO_TKO
df_KOS["fighter1"] = df_KOS.index
df_KOS.set_index(np.arange(1178),inplace = True)
df_KOS.rename(columns={'fighter1':'fighter'},inplace =True)
df_KOS = df_KOS[['fighter','KO/TKO']]

# %%
#Ordem decrescente
df_KOS = df_KOS.sort_values(by = 'KO/TKO',ascending =False)

# %%
df_KOS = df_KOS.dropna()
df_KOS
# Out:
#              fighter  KO/TKO
# 559  Anthony Johnson      11
# 499   Anderson Silva      11
# 356    Vitor Belfort      11
# 568   Cain Velasquez      10
# 241   Donald Cerrone      10
# ..               ...     ...
# 769       Mike Ricci       0
# 221    Mizuto Hirota       0
# 220     Elias Garcia       0
# 772   Yuri Villefort       0
# 589       Yan Cabral       0
#
# [1178 rows x 2 columns]

# %%
filtro = df_KOS['KO/TKO'] > 0
New_df_KOS = df_KOS[filtro]
New_df_KOS
# Out:
#                     fighter  KO/TKO
# 559         Anthony Johnson      11
# 499          Anderson Silva      11
# 356           Vitor Belfort      11
# 568          Cain Velasquez      10
# 241          Donald Cerrone      10
# ..                      ...     ...
# 443             Ryan Benoit       1
# 441             Cyril Asker       1
# 470           Frankie Perez       1
# 407             Vinc Pichel       1
# 465  Alvaro Herrera Mendoza       1
#
# [573 rows x 2 columns]

# %%
plot = New_df_KOS.head(18).plot.bar(y='KO/TKO', x='fighter', title='Números de KO/TKO',figsize=(10,10))

# %% [markdown]
# # Predição de lutas utilizando Random Forest

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'City/State', 'Country', 'Winner',
#        'title_bout', 'weight_class', 'B_total_rounds_fought',
#        'B_total_title_bouts', 'B_wins', 'B_losses', 'B_draw',
#        'B_win_by_KO/TKO', 'B_Stance', 'B_Height_cms', 'B_Reach_cms',
#        'B_Weight_lbs', 'B_age', 'R_total_rounds_fought', 'R_total_title_bouts',
#        'R_wins', 'R_losses', 'R_draw', 'R_win_by_KO/TKO', 'R_Stance',
#        'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs', 'R_age'],
#       dtype='object')

# %%
#Separação das Caracteristicas
Features = ['R_age', 'R_Height_cms', 'R_Weight_lbs', 'R_Reach_cms', 'R_total_title_bouts',
           'B_age','B_Height_cms' ,'B_Weight_lbs' ,'B_Reach_cms', 'B_total_rounds_fought']

# %%
#Definição do rótulo principal
Rotulo = ['Winner']

# %%
df_rf = df[['R_age', 'R_Height_cms', 'R_Weight_lbs', 'R_Reach_cms','B_age', 'R_total_title_bouts',
            'B_Height_cms' ,'B_Weight_lbs' ,'B_Reach_cms', 'B_total_rounds_fought',
            'Winner']]

# %%
df_rf.head(15)
# Out:
#             R_age  R_Height_cms  R_Weight_lbs  R_Reach_cms  B_age  \
# date
# 2019-06-08   29.0        170.18         135.0       180.34   32.0
# 2019-06-08   28.0        165.10         115.0       167.64   33.0
# 2019-06-08   26.0        187.96         264.0       190.50   32.0
# 2019-06-08   31.0        165.10         125.0       167.64   32.0
# 2019-06-08   29.0        162.56         135.0       172.72   26.0
# 2019-06-08   35.0        180.34         155.0       193.04   36.0
# 2019-06-08   33.0        160.02         115.0       162.56   25.0
# 2019-06-08   32.0        162.56         135.0       162.56   31.0
# 2019-06-08   29.0        165.10         115.0       160.02   34.0
# 2019-06-08   30.0        175.26         125.0       172.72   33.0
# 2019-06-08   28.0        190.50         185.0       200.66   28.0
# 2019-06-08   37.0        172.72         145.0       180.34   31.0
# 2019-06-08   34.0        170.18         135.0       175.26   35.0
# 2019-05-18   32.0        167.64         155.0       177.80   27.0
# 2019-05-18   27.0        180.34         170.0       190.50   31.0
#
#             R_total_title_bouts  B_Height_cms  B_Weight_lbs  B_Reach_cms  \
# date
# 2019-06-08                    0        167.64         135.0       165.10
# 2019-06-08                    1        165.10         115.0       162.56
# 2019-06-08                    0        180.34         250.0       185.42
# 2019-06-08                    2        167.64         125.0       167.64
# 2019-06-08                    0        170.18         135.0       170.18
# 2019-06-08                    2        185.42         155.0       185.42
# 2019-06-08                    1        165.10         125.0       167.64
# 2019-06-08                    3        167.64         135.0       170.18
# 2019-06-08                    0        160.02         115.0       162.56
# 2019-06-08                    0        167.64         125.0       165.10
# 2019-06-08                    0        182.88         185.0       187.96
# 2019-06-08                    1        180.34         145.0       182.88
# 2019-06-08                    1        170.18         135.0       172.72
# 2019-05-18                    0        177.80         155.0       180.34
# 2019-05-18                    0        177.80         170.0       182.88
#
#             B_total_rounds_fought Winner
# date
# 2019-06-08                     23    Red
# 2019-06-08                     18    Red
# 2019-06-08                      8   Blue
# 2019-06-08                     29    Red
# 2019-06-08                      9   Blue
# 2019-06-08                     68    Red
# 2019-06-08                     10   Blue
# 2019-06-08                      9    Red
# 2019-06-08                     26    Red
# 2019-06-08                     18    Red
# 2019-06-08                     14   Blue
# 2019-06-08                     10   Blue
# 2019-06-08                      0    Red
# 2019-05-18                      0    Red
# 2019-05-18                      0    Red

# %%
#Importação do LabelEncoder
from sklearn import preprocessing

Rotulo = list(df['Winner'])

#Cria o LabelEncoder
le = preprocessing.LabelEncoder()

#Converte os Dados em números
Label_Encoded=le.fit_transform(Rotulo)

# %%
#Transformando os dados em números
lbl = {'Winner': Label_Encoded}
df_lbl = pd.DataFrame(lbl)

df_rf = df_rf.assign(Winner=Label_Encoded)

# %%
df_rf.head(15)
# Out:
#             R_age  R_Height_cms  R_Weight_lbs  R_Reach_cms  B_age  \
# date
# 2019-06-08   29.0        170.18         135.0       180.34   32.0
# 2019-06-08   28.0        165.10         115.0       167.64   33.0
# 2019-06-08   26.0        187.96         264.0       190.50   32.0
# 2019-06-08   31.0        165.10         125.0       167.64   32.0
# 2019-06-08   29.0        162.56         135.0       172.72   26.0
# 2019-06-08   35.0        180.34         155.0       193.04   36.0
# 2019-06-08   33.0        160.02         115.0       162.56   25.0
# 2019-06-08   32.0        162.56         135.0       162.56   31.0
# 2019-06-08   29.0        165.10         115.0       160.02   34.0
# 2019-06-08   30.0        175.26         125.0       172.72   33.0
# 2019-06-08   28.0        190.50         185.0       200.66   28.0
# 2019-06-08   37.0        172.72         145.0       180.34   31.0
# 2019-06-08   34.0        170.18         135.0       175.26   35.0
# 2019-05-18   32.0        167.64         155.0       177.80   27.0
# 2019-05-18   27.0        180.34         170.0       190.50   31.0
#
#             R_total_title_bouts  B_Height_cms  B_Weight_lbs  B_Reach_cms  \
# date
# 2019-06-08                    0        167.64         135.0       165.10
# 2019-06-08                    1        165.10         115.0       162.56
# 2019-06-08                    0        180.34         250.0       185.42
# 2019-06-08                    2        167.64         125.0       167.64
# 2019-06-08                    0        170.18         135.0       170.18
# 2019-06-08                    2        185.42         155.0       185.42
# 2019-06-08                    1        165.10         125.0       167.64
# 2019-06-08                    3        167.64         135.0       170.18
# 2019-06-08                    0        160.02         115.0       162.56
# 2019-06-08                    0        167.64         125.0       165.10
# 2019-06-08                    0        182.88         185.0       187.96
# 2019-06-08                    1        180.34         145.0       182.88
# 2019-06-08                    1        170.18         135.0       172.72
# 2019-05-18                    0        177.80         155.0       180.34
# 2019-05-18                    0        177.80         170.0       182.88
#
#             B_total_rounds_fought  Winner
# date
# 2019-06-08                     23       2
# 2019-06-08                     18       2
# 2019-06-08                      8       0
# 2019-06-08                     29       2
# 2019-06-08                      9       0
# 2019-06-08                     68       2
# 2019-06-08                     10       0
# 2019-06-08                      9       2
# 2019-06-08                     26       2
# 2019-06-08                     18       2
# 2019-06-08                     14       0
# 2019-06-08                     10       0
# 2019-06-08                      0       2
# 2019-05-18                      0       2
# 2019-05-18                      0       2

# %%
# Importa a função train_test_split
from sklearn.model_selection import train_test_split

X=df_rf[['B_age', 'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs', 'B_total_rounds_fought',
          'R_age', 'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs','R_total_title_bouts']]  # Características
y=df_rf['Winner']  # Rótulos

# Separa a conjunto de dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4) # 60% para treinamento e 40% para teste

# %%
# Importa o classificador Random Forest
from sklearn.ensemble import RandomForestClassifier

# Cria o classificador
clf=RandomForestClassifier(n_estimators=800)

# Treina o modelo usando os conjuntos de treinamento (características e rótulo para predição)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
# Importa o módulo metrics de scikit-learn metrics para cálculo de acurácia
from sklearn import metrics

# Modelo de acurácia; com qual frequência o classificador é correto?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5618971061093248

# %%
# Realiza a predição com base em um nova entrada
clf.predict([[31, 165.10, 170.18, 135, 5, 27, 170.18, 177.80, 135, 2]])
# Out:
# C:\Users\gedsa\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([2], dtype=int64)

# %%
# Realiza a predição com base em um nova entrada
clf.predict([[28.0,152.40,154.94,120, 2, 25.0,160.02,160.02,115.0, 10]])
# Out:
# C:\Users\gedsa\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([2], dtype=int64)

# %%
# Realiza a predição com base em um nova entrada
clf.predict([[20.0,162.40,144.94,115, 7, 27.0,170.02,160.02,130.0, 4]])
# Out:
# C:\Users\gedsa\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([2], dtype=int64)

# %%
# Importa o classificador Random Forest
from sklearn.ensemble import RandomForestClassifier

# Cria o classificador
clf=RandomForestClassifier(n_estimators=800)

# Treina o modelo usando os conjuntos de treinamento (características e rótulo para predição)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=800)

# %%
#n_jobs=2
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=2,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
# Out:
# RandomForestClassifier(n_jobs=2)

# %%
feature_imp = pd.Series(clf.feature_importances_,index=df_rf.columns[0:10]).sort_values(ascending=False)
feature_imp
# Out:
# B_age                    0.143564
# R_total_title_bouts      0.136966
# R_age                    0.124738
# R_Weight_lbs             0.110222
# B_Weight_lbs             0.110066
# R_Height_cms             0.097570
# B_Height_cms             0.094750
# B_Reach_cms              0.069197
# R_Reach_cms              0.067286
# B_total_rounds_fought    0.045641
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Cria um plotagem de barra
sns.barplot(x=feature_imp, y=feature_imp.index)
# Adiciona rótulos para o gráfico
plt.xlabel('Importância da Característica')
plt.ylabel('Características')
plt.title("Visualização da Importância das Características")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Importa a função train_test_split
from sklearn.model_selection import train_test_split

X=df_rf[['B_age', 'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs', 'B_total_rounds_fought',
          'R_age', 'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs','R_total_title_bouts']]  # Características
y=df_rf['Winner']  # Rótulos

# Separa a conjunto de dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.60, random_state=5)

# %%
from sklearn.ensemble import RandomForestClassifier

# Cria o classificador
clf=RandomForestClassifier(n_estimators=100)

# Treina o modelo usando os conjuntos de treinamento (características e rótulo para predição)
clf.fit(X_train,y_train)

# Realiza a predição utilizando o conjunto de teste
y_pred=clf.predict(X_test)

# Importa o módulo metrics de scikit-learn metrics para cálculo de acurácia
from sklearn import metrics

# Modelo de acurácia; com qual frequência o classificador é correto?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5528150134048258
